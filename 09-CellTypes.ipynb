# %% [markdown]
# # Allen Cell Types Database
#
# This notebook will serve as an introduction to the Allen Cell Types database. We'll work with the AllenSDK to see what information we can gain about our cells.
#
# First, we'll `import` the CellTypesCache module. This module provides tools to allow us to get information from the cell types database. We're giving it a **manifest** filename as well. CellTypesCache will create this manifest file, which contains metadata about the cache. You can look under cell_types in your directory, and take a look at the file.
#
# (If you're curious you can see the full documentation for the core package <a href="https://allensdk.readthedocs.io/en/latest/allensdk.core.html">here</a>.)
#
# <b>Note</b>: In order to run the line below, you need to have the AllenSDK installed. You can find information on how to do that <a href="http://alleninstitute.github.io/AllenSDK/install.html">here</a>. If you're running this on the UCSD Datahub, the Allen SDK has already been installed for you.

# %%
#Import the "Cell Types Cache" from the AllenSDK core package
from allensdk.core.cell_types_cache import CellTypesCache

#Import CellTypesApi, which will allow us to query the database.
from allensdk.api.queries.cell_types_api import CellTypesApi

# We'll then initialize the cache as 'ctc' (cell types cache)
ctc = CellTypesCache(manifest_file='cell_types/manifest.json')

# %% [markdown]
# ## Step One: Get Cells & Manipulate Dataframe
#
# Look through <a href="https://allensdk.readthedocs.io/en/latest/allensdk.core.cell_types_cache.html">the documentation for the CellTypesCache</a> for information on the `get_cells` method.
#
# Use the `get_cells` method in the cell below to get information about all of the human cells in the database. Assign the output of this to `human_cells`, and look at the output when it is done.

# %%
human_cells = ctc.get_cells(species=[CellTypesApi.HUMAN])
human_cells
# Out:
# [{'reporter_status': None,
#   'cell_soma_location': [273.0, 354.0, 216.0],
#   'species': 'Homo Sapiens',
#   'id': 525011903,
#   'name': 'H16.03.003.01.14.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12113,
#   'structure_area_abbrev': 'FroL',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 524848408,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [69.0, 254.0, 96.0],
#   'species': 'Homo Sapiens',
#   'id': 528642047,
#   'name': 'H16.06.009.01.02.06.05',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [322.0, 255.0, 92.0],
#   'species': 'Homo Sapiens',
#   'id': 537256313,
#   'name': 'H16.03.006.01.05.02',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 536912860,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [79.0, 273.0, 91.0],
#   'species': 'Homo Sapiens',
#   'id': 519832676,
#   'name': 'H16.03.001.01.09.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 518641172,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.29095064121937},
#  {'reporter_status': None,
#   'cell_soma_location': [66.0, 220.0, 105.0],
#   'species': 'Homo Sapiens',
#   'id': 596020931,
#   'name': 'H17.06.009.11.04.02',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 595954915,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.497824567421906},
#  {'reporter_status': None,
#   'cell_soma_location': [110.0, 122.0, 240.0],
#   'species': 'Homo Sapiens',
#   'id': 569095789,
#   'name': 'H17.06.004.11.05.04',
#   'structure_layer_name': '2',
#   'structure_area_id': 12136,
#   'structure_area_abbrev': 'AnG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 569008241,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.056400381011851},
#  {'reporter_status': None,
#   'cell_soma_location': [312.0, 280.0, 89.0],
#   'species': 'Homo Sapiens',
#   'id': 545608578,
#   'name': 'H16.03.010.13.06.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 545510854,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [79.0, 273.0, 86.0],
#   'species': 'Homo Sapiens',
#   'id': 561467633,
#   'name': 'H16.06.013.12.08.05',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 561414332,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 528706755,
#   'name': 'H16.06.009.01.01.15.01',
#   'structure_layer_name': '2',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'dendrite-only',
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.134666551732475},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 111.0],
#   'species': 'Homo Sapiens',
#   'id': 530055374,
#   'name': 'H16.06.010.01.03.14.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [127.0, 354.0, 219.0],
#   'species': 'Homo Sapiens',
#   'id': 531520637,
#   'name': 'H16.06.007.01.05.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12113,
#   'structure_area_abbrev': 'FroL',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 518229880,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.388676047786476},
#  {'reporter_status': None,
#   'cell_soma_location': [92.0, 260.0, 67.0],
#   'species': 'Homo Sapiens',
#   'id': 530097064,
#   'name': 'H16.06.010.01.01.06.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12142,
#   'structure_area_abbrev': 'ITG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 261.0, 109.0],
#   'species': 'Homo Sapiens',
#   'id': 488418919,
#   'name': 'H15.06.017.03.04.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 487502058,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [326.0, 243.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 616647103,
#   'name': 'H17.03.005.11.09.02',
#   'structure_layer_name': '2',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 587641390,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.0929658145881198},
#  {'reporter_status': None,
#   'cell_soma_location': [68.0, 252.0, 106.0],
#   'species': 'Homo Sapiens',
#   'id': 601958555,
#   'name': 'H17.03.010.11.13.06',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 601901227,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.514497947267724},
#  {'reporter_status': None,
#   'cell_soma_location': [82.0, 272.0, 81.0],
#   'species': 'Homo Sapiens',
#   'id': 567776248,
#   'name': 'H17.06.003.12.06.03',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 567704703,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [322.0, 246.0, 94.0],
#   'species': 'Homo Sapiens',
#   'id': 542143598,
#   'name': 'H16.03.008.11.11.03',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 541755848,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.62013096297291},
#  {'reporter_status': None,
#   'cell_soma_location': [127.0, 354.0, 219.0],
#   'species': 'Homo Sapiens',
#   'id': 531520401,
#   'name': 'H16.06.007.01.07.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12113,
#   'structure_area_abbrev': 'FroL',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 518229880,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.428976771450575},
#  {'reporter_status': None,
#   'cell_soma_location': [67.0, 256.0, 110.0],
#   'species': 'Homo Sapiens',
#   'id': 527942865,
#   'name': 'H16.06.008.01.26.04',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 527747035,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.694465802153644},
#  {'reporter_status': None,
#   'cell_soma_location': [66.0, 220.0, 105.0],
#   'species': 'Homo Sapiens',
#   'id': 596049209,
#   'name': 'H17.06.009.11.04.05',
#   'structure_layer_name': '1',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 595954915,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 111.0],
#   'species': 'Homo Sapiens',
#   'id': 529807751,
#   'name': 'H16.06.010.01.03.04.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.24222476945534},
#  {'reporter_status': None,
#   'cell_soma_location': [317.0, 268.0, 88.0],
#   'species': 'Homo Sapiens',
#   'id': 539563223,
#   'name': 'H16.06.011.01.01.14.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 539522943,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [326.0, 250.0, 116.0],
#   'species': 'Homo Sapiens',
#   'id': 489308885,
#   'name': 'H15.06.018.02.03.01',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 488771222,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 257.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 508280385,
#   'name': 'H16.06.004.01.04.02',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [68.0, 252.0, 106.0],
#   'species': 'Homo Sapiens',
#   'id': 601927090,
#   'name': 'H17.03.010.11.13.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 601901227,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.381666850586892},
#  {'reporter_status': None,
#   'cell_soma_location': [270.0, 351.0, 219.0],
#   'species': 'Homo Sapiens',
#   'id': 517673596,
#   'name': 'H16.06.006.01.04.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12113,
#   'structure_area_abbrev': 'FroL',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 517325289,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.53257155492601},
#  {'reporter_status': None,
#   'cell_soma_location': [66.0, 220.0, 105.0],
#   'species': 'Homo Sapiens',
#   'id': 595999306,
#   'name': 'H17.06.009.11.04.01',
#   'structure_layer_name': '1',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'sparsely spiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 595954915,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.0379253039118483},
#  {'reporter_status': None,
#   'cell_soma_location': [67.0, 256.0, 110.0],
#   'species': 'Homo Sapiens',
#   'id': 528042185,
#   'name': 'H16.06.008.01.20.05',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 527747035,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.533540474362589},
#  {'reporter_status': None,
#   'cell_soma_location': [308.0, 310.0, 185.0],
#   'species': 'Homo Sapiens',
#   'id': 488386626,
#   'name': 'H15.06.016.01.03.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12117,
#   'structure_area_abbrev': 'IFG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 486909083,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.379774663425516},
#  {'reporter_status': None,
#   'cell_soma_location': [69.0, 254.0, 96.0],
#   'species': 'Homo Sapiens',
#   'id': 528638057,
#   'name': 'H16.06.009.01.02.05.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.393438562087628},
#  {'reporter_status': None,
#   'cell_soma_location': [72.0, 263.0, 103.0],
#   'species': 'Homo Sapiens',
#   'id': 571427524,
#   'name': 'H17.06.005.12.15.01',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 571364629,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.4645510524009},
#  {'reporter_status': None,
#   'cell_soma_location': [68.0, 252.0, 106.0],
#   'species': 'Homo Sapiens',
#   'id': 601950719,
#   'name': 'H17.03.010.11.13.05',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 601901227,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 257.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 508282493,
#   'name': 'H16.06.004.01.04.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.168279512608661},
#  {'reporter_status': None,
#   'cell_soma_location': [92.0, 260.0, 67.0],
#   'species': 'Homo Sapiens',
#   'id': 529988200,
#   'name': 'H16.06.010.01.01.11.02',
#   'structure_layer_name': '6',
#   'structure_area_id': 12142,
#   'structure_area_abbrev': 'ITG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [274.0, 331.0, 228.0],
#   'species': 'Homo Sapiens',
#   'id': 576132767,
#   'name': 'H17.06.007.11.05.05',
#   'structure_layer_name': '5',
#   'structure_area_id': 12116,
#   'structure_area_abbrev': 'MFG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 576060516,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.602640058587847},
#  {'reporter_status': None,
#   'cell_soma_location': [72.0, 257.0, 90.0],
#   'species': 'Homo Sapiens',
#   'id': 571709783,
#   'name': 'H17.06.006.11.08.07',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 571458187,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.262379643149249},
#  {'reporter_status': None,
#   'cell_soma_location': [326.0, 243.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 587719226,
#   'name': 'H17.03.005.11.08.02',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 587641390,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [79.0, 273.0, 86.0],
#   'species': 'Homo Sapiens',
#   'id': 562381326,
#   'name': 'H16.06.013.11.18.03',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 561414332,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 528612139,
#   'name': 'H16.06.009.01.01.05.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [72.0, 257.0, 90.0],
#   'species': 'Homo Sapiens',
#   'id': 571718621,
#   'name': 'H17.06.006.11.08.08',
#   'structure_layer_name': '2',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'sparsely spiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 571458187,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.0839736412742554},
#  {'reporter_status': None,
#   'cell_soma_location': [127.0, 354.0, 219.0],
#   'species': 'Homo Sapiens',
#   'id': 531517518,
#   'name': 'H16.06.007.01.08.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12113,
#   'structure_area_abbrev': 'FroL',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 518229880,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [317.0, 266.0, 93.0],
#   'species': 'Homo Sapiens',
#   'id': 613333217,
#   'name': 'H17.03.009.11.11.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 596832620,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 257.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 508281653,
#   'name': 'H16.06.004.01.10.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 258.0, 104.0],
#   'species': 'Homo Sapiens',
#   'id': 508421103,
#   'name': 'H16.06.004.02.05.02',
#   'structure_layer_name': '2',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.112938548497462},
#  {'reporter_status': None,
#   'cell_soma_location': [313.0, 280.0, 94.0],
#   'species': 'Homo Sapiens',
#   'id': 569823971,
#   'name': 'H17.03.002.11.04.03',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 569800644,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [72.0, 263.0, 103.0],
#   'species': 'Homo Sapiens',
#   'id': 571508482,
#   'name': 'H17.06.005.12.15.07',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 571364629,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.177058638973263},
#  {'reporter_status': None,
#   'cell_soma_location': [79.0, 273.0, 86.0],
#   'species': 'Homo Sapiens',
#   'id': 561432315,
#   'name': 'H16.06.013.11.16.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 561414332,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.267447452504768},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 111.0],
#   'species': 'Homo Sapiens',
#   'id': 530062215,
#   'name': 'H16.06.010.01.03.14.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.296670071608455},
#  {'reporter_status': None,
#   'cell_soma_location': [67.0, 256.0, 110.0],
#   'species': 'Homo Sapiens',
#   'id': 527891102,
#   'name': 'H16.06.008.01.31.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 527747035,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.456993448482303},
#  {'reporter_status': None,
#   'cell_soma_location': [317.0, 268.0, 88.0],
#   'species': 'Homo Sapiens',
#   'id': 539640410,
#   'name': 'H16.06.011.01.01.05.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 539522943,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.114959870640455},
#  {'reporter_status': None,
#   'cell_soma_location': [88.0, 272.0, 74.0],
#   'species': 'Homo Sapiens',
#   'id': 541536216,
#   'name': 'H16.03.007.01.01.08.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 541516760,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.324403328055805},
#  {'reporter_status': None,
#   'cell_soma_location': [79.0, 273.0, 91.0],
#   'species': 'Homo Sapiens',
#   'id': 519849529,
#   'name': 'H16.03.001.01.09.02',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 518641172,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [333.0, 229.0, 114.0],
#   'species': 'Homo Sapiens',
#   'id': 614230805,
#   'name': 'H17.03.011.11.04.05',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 614077275,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.388292563276911},
#  {'reporter_status': None,
#   'cell_soma_location': [308.0, 310.0, 185.0],
#   'species': 'Homo Sapiens',
#   'id': 488386431,
#   'name': 'H15.06.016.01.05.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12117,
#   'structure_area_abbrev': 'IFG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 486909083,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [69.0, 254.0, 96.0],
#   'species': 'Homo Sapiens',
#   'id': 528631988,
#   'name': 'H16.06.009.01.02.06.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 528601797,
#   'name': 'H16.06.009.01.01.08.02',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 261.0, 109.0],
#   'species': 'Homo Sapiens',
#   'id': 488400701,
#   'name': 'H15.06.017.03.07.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 487502058,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 258.0, 104.0],
#   'species': 'Homo Sapiens',
#   'id': 508413678,
#   'name': 'H16.06.004.02.12.02',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [78.0, 272.0, 91.0],
#   'species': 'Homo Sapiens',
#   'id': 614635228,
#   'name': 'H17.06.003.11.03.02',
#   'structure_layer_name': '6',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 567704703,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.753948329545121},
#  {'reporter_status': None,
#   'cell_soma_location': [303.0, 281.0, 129.0],
#   'species': 'Homo Sapiens',
#   'id': 643572206,
#   'name': 'H17.06.013.12.03.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12147,
#   'structure_area_abbrev': 'PLP',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 643488707,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.287786959479981},
#  {'reporter_status': None,
#   'cell_soma_location': [92.0, 260.0, 67.0],
#   'species': 'Homo Sapiens',
#   'id': 529908238,
#   'name': 'H16.06.010.01.01.13.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12142,
#   'structure_area_abbrev': 'ITG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [127.0, 354.0, 219.0],
#   'species': 'Homo Sapiens',
#   'id': 531526662,
#   'name': 'H16.06.007.01.08.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12113,
#   'structure_area_abbrev': 'FroL',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 518229880,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 257.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 508410761,
#   'name': 'H16.06.004.01.13.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.184084254852582},
#  {'reporter_status': None,
#   'cell_soma_location': [303.0, 281.0, 129.0],
#   'species': 'Homo Sapiens',
#   'id': 643582610,
#   'name': 'H17.06.013.12.03.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12147,
#   'structure_area_abbrev': 'PLP',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 643488707,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.39546611585759},
#  {'reporter_status': None,
#   'cell_soma_location': [92.0, 260.0, 67.0],
#   'species': 'Homo Sapiens',
#   'id': 530062268,
#   'name': 'H16.06.010.01.01.04.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12142,
#   'structure_area_abbrev': 'ITG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [322.0, 255.0, 92.0],
#   'species': 'Homo Sapiens',
#   'id': 537307503,
#   'name': 'H16.03.006.01.04.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 536912860,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 257.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 508285405,
#   'name': 'H16.06.004.01.10.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [284.0, 361.0, 195.0],
#   'species': 'Homo Sapiens',
#   'id': 548473051,
#   'name': 'H16.06.012.11.08.05',
#   'structure_layer_name': '3',
#   'structure_area_id': 12116,
#   'structure_area_abbrev': 'MFG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 548298531,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.22668688129183},
#  {'reporter_status': None,
#   'cell_soma_location': [79.0, 273.0, 86.0],
#   'species': 'Homo Sapiens',
#   'id': 561464809,
#   'name': 'H16.06.013.12.08.02',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 561414332,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [273.0, 354.0, 216.0],
#   'species': 'Homo Sapiens',
#   'id': 525018757,
#   'name': 'H16.03.003.01.19.02',
#   'structure_layer_name': '2',
#   'structure_area_id': 12113,
#   'structure_area_abbrev': 'FroL',
#   'transgenic_line': '',
#   'dendrite_type': 'sparsely spiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 524848408,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.0656980585070159},
#  {'reporter_status': None,
#   'cell_soma_location': [72.0, 263.0, 103.0],
#   'species': 'Homo Sapiens',
#   'id': 571483807,
#   'name': 'H17.06.005.12.15.05',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 571364629,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.243430792462741},
#  {'reporter_status': None,
#   'cell_soma_location': [110.0, 122.0, 240.0],
#   'species': 'Homo Sapiens',
#   'id': 569101823,
#   'name': 'H17.06.004.11.06.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12136,
#   'structure_area_abbrev': 'AnG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 569008241,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [72.0, 263.0, 103.0],
#   'species': 'Homo Sapiens',
#   'id': 571435969,
#   'name': 'H17.06.005.12.10.04',
#   'structure_layer_name': '2',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 571364629,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.0992932348271212},
#  {'reporter_status': None,
#   'cell_soma_location': [284.0, 361.0, 195.0],
#   'species': 'Homo Sapiens',
#   'id': 548421866,
#   'name': 'H16.06.012.11.06.02',
#   'structure_layer_name': '5',
#   'structure_area_id': 12116,
#   'structure_area_abbrev': 'MFG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 548298531,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.707391060403448},
#  {'reporter_status': None,
#   'cell_soma_location': [317.0, 268.0, 88.0],
#   'species': 'Homo Sapiens',
#   'id': 539540199,
#   'name': 'H16.06.011.01.01.10.03',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 539522943,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [270.0, 351.0, 219.0],
#   'species': 'Homo Sapiens',
#   'id': 531529716,
#   'name': 'H16.06.006.01.05.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12113,
#   'structure_area_abbrev': 'FroL',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 517325289,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [317.0, 270.0, 100.0],
#   'species': 'Homo Sapiens',
#   'id': 539563673,
#   'name': 'H16.06.011.01.01.18.01.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 539522943,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 528609885,
#   'name': 'H16.06.009.01.01.08.03',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 111.0],
#   'species': 'Homo Sapiens',
#   'id': 529856350,
#   'name': 'H16.06.010.01.03.08.03',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [81.0, 149.0, 216.0],
#   'species': 'Homo Sapiens',
#   'id': 545193484,
#   'name': 'H16.03.009.11.13.03',
#   'structure_layer_name': '5',
#   'structure_area_id': 12136,
#   'structure_area_abbrev': 'AnG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 545106104,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 257.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 508309649,
#   'name': 'H16.06.004.01.03.05',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.616803734919065},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 528617195,
#   'name': 'H16.06.009.01.01.08.05',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [326.0, 243.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 587710671,
#   'name': 'H17.03.005.11.08.01',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 587641390,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.611807338955647},
#  {'reporter_status': None,
#   'cell_soma_location': [83.0, 268.0, 81.0],
#   'species': 'Homo Sapiens',
#   'id': 571517139,
#   'name': 'H17.06.005.13.09.01',
#   'structure_layer_name': '2',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 571364629,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 528631714,
#   'name': 'H16.06.009.01.01.09.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [79.0, 273.0, 86.0],
#   'species': 'Homo Sapiens',
#   'id': 561465305,
#   'name': 'H16.06.013.12.08.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 561414332,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.352963627143144},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 257.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 508390405,
#   'name': 'H16.06.004.01.09.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [320.0, 274.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 526816192,
#   'name': 'H16.03.005.01.09.06',
#   'structure_layer_name': '5',
#   'structure_area_id': 12139,
#   'structure_area_abbrev': 'TemL',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 526633593,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [72.0, 263.0, 103.0],
#   'species': 'Homo Sapiens',
#   'id': 571471295,
#   'name': 'H17.06.005.12.15.04',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 571364629,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.548023181469825},
#  {'reporter_status': None,
#   'cell_soma_location': [88.0, 272.0, 74.0],
#   'species': 'Homo Sapiens',
#   'id': 541566142,
#   'name': 'H16.03.007.01.01.04.05',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 541516760,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [326.0, 243.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 587770251,
#   'name': 'H17.03.005.11.10.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 587641390,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [320.0, 274.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 526785799,
#   'name': 'H16.03.005.01.09.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12139,
#   'structure_area_abbrev': 'TemL',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 526633593,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.129965552937216},
#  {'reporter_status': None,
#   'cell_soma_location': [333.0, 229.0, 114.0],
#   'species': 'Homo Sapiens',
#   'id': 614197612,
#   'name': 'H17.03.011.11.09.04',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 614077275,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.751768658311418},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 528697733,
#   'name': 'H16.06.009.01.01.14.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [67.0, 256.0, 110.0],
#   'species': 'Homo Sapiens',
#   'id': 528011097,
#   'name': 'H16.06.008.01.22.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 527747035,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 257.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 508390609,
#   'name': 'H16.06.004.01.11.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [67.0, 256.0, 110.0],
#   'species': 'Homo Sapiens',
#   'id': 527901472,
#   'name': 'H16.06.008.01.31.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 527747035,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [284.0, 361.0, 195.0],
#   'species': 'Homo Sapiens',
#   'id': 548434716,
#   'name': 'H16.06.012.11.04.02',
#   'structure_layer_name': '5',
#   'structure_area_id': 12116,
#   'structure_area_abbrev': 'MFG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 548298531,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 528734156,
#   'name': 'H16.06.009.01.01.14.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [67.0, 256.0, 110.0],
#   'species': 'Homo Sapiens',
#   'id': 528038990,
#   'name': 'H16.06.008.01.20.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
# ...
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.751316296453857},
#  {'reporter_status': None,
#   'cell_soma_location': [274.0, 331.0, 228.0],
#   'species': 'Homo Sapiens',
#   'id': 576112128,
#   'name': 'H17.06.007.11.05.03',
#   'structure_layer_name': '4',
#   'structure_area_id': 12116,
#   'structure_area_abbrev': 'MFG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 576060516,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 111.0],
#   'species': 'Homo Sapiens',
#   'id': 529863215,
#   'name': 'H16.06.010.01.03.05.02',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.495427953498247},
#  {'reporter_status': None,
#   'cell_soma_location': [110.0, 122.0, 240.0],
#   'species': 'Homo Sapiens',
#   'id': 569075240,
#   'name': 'H17.06.004.11.05.01',
#   'structure_layer_name': '4',
#   'structure_area_id': 12136,
#   'structure_area_abbrev': 'AnG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 569008241,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [333.0, 236.0, 122.0],
#   'species': 'Homo Sapiens',
#   'id': 611592806,
#   'name': 'H17.06.012.14.08.02',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 611526465,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 111.0],
#   'species': 'Homo Sapiens',
#   'id': 529877874,
#   'name': 'H16.06.010.01.03.06.01',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 258.0, 104.0],
#   'species': 'Homo Sapiens',
#   'id': 508420652,
#   'name': 'H16.06.004.02.12.03',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [78.0, 272.0, 91.0],
#   'species': 'Homo Sapiens',
#   'id': 567742660,
#   'name': 'H17.06.003.11.05.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 567704703,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.374362854360203},
#  {'reporter_status': None,
#   'cell_soma_location': [85.0, 271.0, 103.0],
#   'species': 'Homo Sapiens',
#   'id': 520471727,
#   'name': 'H16.03.002.01.08.02',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 520276747,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [72.0, 263.0, 103.0],
#   'species': 'Homo Sapiens',
#   'id': 571516327,
#   'name': 'H17.06.005.12.05.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 571364629,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [308.0, 310.0, 185.0],
#   'species': 'Homo Sapiens',
#   'id': 486940963,
#   'name': 'H15.06.016.01.04.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12117,
#   'structure_area_abbrev': 'IFG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 486909083,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 261.0, 109.0],
#   'species': 'Homo Sapiens',
#   'id': 488418027,
#   'name': 'H15.06.017.03.03.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 487502058,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.23853991543599},
#  {'reporter_status': None,
#   'cell_soma_location': [78.0, 272.0, 91.0],
#   'species': 'Homo Sapiens',
#   'id': 567747448,
#   'name': 'H17.06.003.11.08.05',
#   'structure_layer_name': '2',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 567704703,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [92.0, 260.0, 67.0],
#   'species': 'Homo Sapiens',
#   'id': 529909601,
#   'name': 'H16.06.010.01.01.10.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12142,
#   'structure_area_abbrev': 'ITG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [72.0, 257.0, 90.0],
#   'species': 'Homo Sapiens',
#   'id': 571659461,
#   'name': 'H17.06.006.11.10.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 571458187,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.149318345796553},
#  {'reporter_status': None,
#   'cell_soma_location': [317.0, 268.0, 88.0],
#   'species': 'Homo Sapiens',
#   'id': 539561039,
#   'name': 'H16.06.011.01.01.14.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 539522943,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 111.0],
#   'species': 'Homo Sapiens',
#   'id': 529833429,
#   'name': 'H16.06.010.01.03.08.02',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [317.0, 268.0, 88.0],
#   'species': 'Homo Sapiens',
#   'id': 539542640,
#   'name': 'H16.06.011.01.01.10.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 539522943,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.112403302648501},
#  {'reporter_status': None,
#   'cell_soma_location': [88.0, 272.0, 74.0],
#   'species': 'Homo Sapiens',
#   'id': 541540615,
#   'name': 'H16.03.007.01.01.08.02',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 541516760,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [92.0, 260.0, 67.0],
#   'species': 'Homo Sapiens',
#   'id': 529889679,
#   'name': 'H16.06.010.01.01.10.01',
#   'structure_layer_name': '3',
#   'structure_area_id': 12142,
#   'structure_area_abbrev': 'ITG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 529678110,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.162400495695793},
#  {'reporter_status': None,
#   'cell_soma_location': [322.0, 255.0, 92.0],
#   'species': 'Homo Sapiens',
#   'id': 537313600,
#   'name': 'H16.03.006.01.03.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 536912860,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.261770055284043},
#  {'reporter_status': None,
#   'cell_soma_location': [313.0, 280.0, 94.0],
#   'species': 'Homo Sapiens',
#   'id': 569844159,
#   'name': 'H17.03.002.11.04.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 569800644,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.21204070000922},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 260.0, 108.0],
#   'species': 'Homo Sapiens',
#   'id': 528625591,
#   'name': 'H16.06.009.01.01.06.04',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [81.0, 149.0, 216.0],
#   'species': 'Homo Sapiens',
#   'id': 545188095,
#   'name': 'H16.03.009.11.14.01',
#   'structure_layer_name': '5',
#   'structure_area_id': 12136,
#   'structure_area_abbrev': 'AnG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 545106104,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [70.0, 249.0, 103.0],
#   'species': 'Homo Sapiens',
#   'id': 505690787,
#   'name': 'H16.06.003.01.08.02',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 504919864,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [69.0, 254.0, 96.0],
#   'species': 'Homo Sapiens',
#   'id': 528636794,
#   'name': 'H16.06.009.01.02.03.01',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 528574320,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.558691608635989},
#  {'reporter_status': None,
#   'cell_soma_location': [274.0, 331.0, 228.0],
#   'species': 'Homo Sapiens',
#   'id': 576107598,
#   'name': 'H17.06.007.11.08.02',
#   'structure_layer_name': '2',
#   'structure_area_id': 12116,
#   'structure_area_abbrev': 'MFG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'tumor',
#   'donor_id': 576060516,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.118443475606138},
#  {'reporter_status': None,
#   'cell_soma_location': [270.0, 351.0, 219.0],
#   'species': 'Homo Sapiens',
#   'id': 517689107,
#   'name': 'H16.06.006.01.06.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12113,
#   'structure_area_abbrev': 'FroL',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': None,
#   'disease_state': 'tumor',
#   'donor_id': 517325289,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [333.0, 236.0, 122.0],
#   'species': 'Homo Sapiens',
#   'id': 611823070,
#   'name': 'H17.06.012.14.10.02',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 611526465,
#   'structure_hemisphere': 'right',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [325.0, 257.0, 102.0],
#   'species': 'Homo Sapiens',
#   'id': 508298270,
#   'name': 'H16.06.004.01.04.05',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 504921484,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.0954777859793282},
#  {'reporter_status': None,
#   'cell_soma_location': [312.0, 280.0, 89.0],
#   'species': 'Homo Sapiens',
#   'id': 545612828,
#   'name': 'H16.03.010.13.05.03',
#   'structure_layer_name': '3',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'intact',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 545510854,
#   'structure_hemisphere': 'right',
#   'normalized_depth': 0.223071224985407},
#  {'reporter_status': None,
#   'cell_soma_location': [67.0, 256.0, 110.0],
#   'species': 'Homo Sapiens',
#   'id': 527952884,
#   'name': 'H16.06.008.01.31.06',
#   'structure_layer_name': '4',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 527747035,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.576931185341878},
#  {'reporter_status': None,
#   'cell_soma_location': [89.0, 227.0, 87.0],
#   'species': 'Homo Sapiens',
#   'id': 488701127,
#   'name': 'H15.03.006.01.10.01',
#   'structure_layer_name': '5',
#   'structure_area_id': 12142,
#   'structure_area_abbrev': 'ITG',
#   'transgenic_line': '',
#   'dendrite_type': 'spiny',
#   'apical': 'truncated',
#   'reconstruction_type': None,
#   'disease_state': 'epilepsy',
#   'donor_id': 487505044,
#   'structure_hemisphere': 'left',
#   'normalized_depth': None},
#  {'reporter_status': None,
#   'cell_soma_location': [79.0, 273.0, 86.0],
#   'species': 'Homo Sapiens',
#   'id': 561469082,
#   'name': 'H16.06.013.12.08.06',
#   'structure_layer_name': '5',
#   'structure_area_id': 12141,
#   'structure_area_abbrev': 'MTG',
#   'transgenic_line': '',
#   'dendrite_type': 'aspiny',
#   'apical': 'NA',
#   'reconstruction_type': 'full',
#   'disease_state': 'epilepsy',
#   'donor_id': 561414332,
#   'structure_hemisphere': 'left',
#   'normalized_depth': 0.673116370394225}]

# %% [markdown]
# Chances are, your output looks a bit messy. This is where pandas can really come in handy! Convert `human_cells` into a Pandas Dataframe by:
# 1. Importing `pandas` as `pd`
# 2. Creating a dataframe with `pd.DataFrame()`
# 3. Assigning that dataframe to `human_df`
# 4. Showing the first five rows of the df using the `.head()` method.
#
# Note: If you're having trouble with Pandas, it can help to look at <a href="https://pandas.pydata.org/pandas-docs/stable/user_guide/">the user guide</a>.

# %%
import pandas as pd

human_df = pd.DataFrame(human_cells)
human_df.head()
# Out:
#   reporter_status     cell_soma_location       species         id  \
# 0            None  [273.0, 354.0, 216.0]  Homo Sapiens  525011903
# 1            None    [69.0, 254.0, 96.0]  Homo Sapiens  528642047
# 2            None   [322.0, 255.0, 92.0]  Homo Sapiens  537256313
# 3            None    [79.0, 273.0, 91.0]  Homo Sapiens  519832676
# 4            None   [66.0, 220.0, 105.0]  Homo Sapiens  596020931
#
#                      name structure_layer_name  structure_area_id  \
# 0     H16.03.003.01.14.02                    3              12113
# 1  H16.06.009.01.02.06.05                    5              12141
# 2     H16.03.006.01.05.02                    4              12141
# 3     H16.03.001.01.09.01                    3              12141
# 4     H17.06.009.11.04.02                    4              12141
#
#   structure_area_abbrev transgenic_line dendrite_type     apical  \
# 0                  FroL                         spiny     intact
# 1                   MTG                        aspiny         NA
# 2                   MTG                         spiny  truncated
# 3                   MTG                         spiny  truncated
# 4                   MTG                        aspiny         NA
#
#   reconstruction_type disease_state   donor_id structure_hemisphere  \
# 0                None      epilepsy  524848408                right
# 1                None      epilepsy  528574320                 left
# 2                None      epilepsy  536912860                right
# 3                full      epilepsy  518641172                 left
# 4                full         tumor  595954915                 left
#
#    normalized_depth
# 0               NaN
# 1               NaN
# 2               NaN
# 3          0.290951
# 4          0.497825

# %% [markdown]
# Let's get some information about our cells. We can use `len()` on a dataframe to get the number of rows. Alternatively, we can use the `count()` method on our dataframe to get detailed information for each column. For our purposes today, let's just get the number of rows, which is equivalent to the number of observations.
#
# 1. Use the `count()` method to see how many observations there are in each of the columns. Why might some be missing?
# 2. Use `len()` to see the length of the whole dataframe and assign the output to `n_human_cells`.

# %%
n_human_cells = len(human_df)
print(n_human_cells)
# Out:
# 411

# %% [markdown]
# At the moment, our rows don't have any useful information -- they're simply a list of indices. We can reassign the row values by using the method `set_index`. Execute this method to set the 'id' column as the index, and reassign your dataframe as `human_df`.

# %%
human_df = human_df.set_index('id')
human_df.head()
# Out:
#           reporter_status     cell_soma_location       species  \
# id
# 525011903            None  [273.0, 354.0, 216.0]  Homo Sapiens
# 528642047            None    [69.0, 254.0, 96.0]  Homo Sapiens
# 537256313            None   [322.0, 255.0, 92.0]  Homo Sapiens
# 519832676            None    [79.0, 273.0, 91.0]  Homo Sapiens
# 596020931            None   [66.0, 220.0, 105.0]  Homo Sapiens
#
#                              name structure_layer_name  structure_area_id  \
# id
# 525011903     H16.03.003.01.14.02                    3              12113
# 528642047  H16.06.009.01.02.06.05                    5              12141
# 537256313     H16.03.006.01.05.02                    4              12141
# 519832676     H16.03.001.01.09.01                    3              12141
# 596020931     H17.06.009.11.04.02                    4              12141
#
#           structure_area_abbrev transgenic_line dendrite_type     apical  \
# id
# 525011903                  FroL                         spiny     intact
# 528642047                   MTG                        aspiny         NA
# 537256313                   MTG                         spiny  truncated
# 519832676                   MTG                         spiny  truncated
# 596020931                   MTG                        aspiny         NA
#
#           reconstruction_type disease_state   donor_id structure_hemisphere  \
# id
# 525011903                None      epilepsy  524848408                right
# 528642047                None      epilepsy  528574320                 left
# 537256313                None      epilepsy  536912860                right
# 519832676                full      epilepsy  518641172                 left
# 596020931                full         tumor  595954915                 left
#
#            normalized_depth
# id
# 525011903               NaN
# 528642047               NaN
# 537256313               NaN
# 519832676          0.290951
# 596020931          0.497825

# %% [markdown]
# It would help to know what information is in our dataset. In other words, what is across the columns at the top? We can get a list by accessing the attribute `.columns`. Assign the output of this method to `human_df_columns`.

# %%
human_df_columns = human_df.columns
print(human_df_columns)
# Out:
# Index(['reporter_status', 'cell_soma_location', 'species', 'name',
#        'structure_layer_name', 'structure_area_id', 'structure_area_abbrev',
#        'transgenic_line', 'dendrite_type', 'apical', 'reconstruction_type',
#        'disease_state', 'donor_id', 'structure_hemisphere',
#        'normalized_depth'],
#       dtype='object')

# %% [markdown]
# We can access individual columns with the notation `dataframe['column name']`. Check out the `dendrite_type` column by using this notation.

# %%
human_df['dendrite_type']
# Out:
# id
# 525011903     spiny
# 528642047    aspiny
# 537256313     spiny
# 519832676     spiny
# 596020931    aspiny
#               ...
# 508298270     spiny
# 545612828     spiny
# 527952884     spiny
# 488701127     spiny
# 561469082    aspiny
# Name: dendrite_type, Length: 411, dtype: object

# %% [markdown]
# Like numpy arrays, we can use boolean indexing to filter our pandas dataframe. Our dataframe has data on two different dendrite types. Filter your dataframe by using the following syntax:
# ```
# new_df = original_df[original_df['Column of Interest'] == 'Desired Value']
# ```
# In plain english, what this is saying is: save a dataframe from the original dataframe, where the original dataframe values in my Column of Interest are equal to my Desired Value.
#
# 1. Assign your new dataframe and give it a reasonable name (e.g., `spiny_df`)
# 2. Create a second dataframe for the *other* dendrite type.

# %%
spiny_df = human_df[human_df['dendrite_type'] == 'spiny']
spiny_df.head()
# Out:
#           reporter_status     cell_soma_location       species  \
# id
# 525011903            None  [273.0, 354.0, 216.0]  Homo Sapiens
# 537256313            None   [322.0, 255.0, 92.0]  Homo Sapiens
# 519832676            None    [79.0, 273.0, 91.0]  Homo Sapiens
# 569095789            None  [110.0, 122.0, 240.0]  Homo Sapiens
# 545608578            None   [312.0, 280.0, 89.0]  Homo Sapiens
#
#                           name structure_layer_name  structure_area_id  \
# id
# 525011903  H16.03.003.01.14.02                    3              12113
# 537256313  H16.03.006.01.05.02                    4              12141
# 519832676  H16.03.001.01.09.01                    3              12141
# 569095789  H17.06.004.11.05.04                    2              12136
# 545608578  H16.03.010.13.06.01                    3              12141
#
#           structure_area_abbrev transgenic_line dendrite_type     apical  \
# id
# 525011903                  FroL                         spiny     intact
# 537256313                   MTG                         spiny  truncated
# 519832676                   MTG                         spiny  truncated
# 569095789                   AnG                         spiny     intact
# 545608578                   MTG                         spiny     intact
#
#           reconstruction_type disease_state   donor_id structure_hemisphere  \
# id
# 525011903                None      epilepsy  524848408                right
# 537256313                None      epilepsy  536912860                right
# 519832676                full      epilepsy  518641172                 left
# 569095789                full         tumor  569008241                 left
# 545608578                None      epilepsy  545510854                right
#
#            normalized_depth
# id
# 525011903               NaN
# 537256313               NaN
# 519832676          0.290951
# 569095789          0.056400
# 545608578               NaN

# %% [markdown]
# ## Step Two: Get Electrophysiology Data
#
# At this point, you might have realized that this dataframe doesn't contain any data about the electrophysiology -- it's just metadata about the cells. In order to get information about the electrophysiological properties of these cells, we need to use the `get_ephys_features()` method on our instance of the cell types cache.
#
# 1. Execute the `get_ephys_features` method on our cell types instance and assign the output of this to `ephys_features`.
# 2. Convert `ephys_features` into a pandas dataframe.
# 3. Re-assign the index to be the column labeled 'specimen_id' of the cell (and reassign to `ephys_features`). 'specimen_id' is the label that can link this dataframe to our metadata (human_df) dataframe.

# %%
ephys_features = pd.DataFrame(ctc.get_ephys_features()).set_index('specimen_id')
ephys_features.head()
# Out:
#              adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# specimen_id
# 529878215           NaN  134.700000       22.697498     8.335459e-02
# 548459652           NaN         NaN      -24.887498    -3.913630e-19
# 579978640      0.009770   39.044800      -46.765002     5.267857e-01
# 439024551     -0.007898  117.816429        5.996250     1.542553e-01
# 515188639      0.022842   68.321429       14.910000     1.714041e-01
#
#              fast_trough_t_long_square  fast_trough_t_ramp  \
# specimen_id
# 529878215                     1.187680           13.295200
# 548459652                     1.099840           20.650105
# 579978640                     1.157840            2.551310
# 439024551                     1.989165            9.572025
# 515188639                     1.081980            2.462880
#
#              fast_trough_t_short_square  fast_trough_v_long_square  \
# specimen_id
# 529878215                      1.025916                 -56.375004
# 548459652                      1.025460                 -54.000000
# 579978640                      1.025387                 -59.500000
# 439024551                      1.028733                 -47.531250
# 515188639                      1.025620                 -48.437504
#
#              fast_trough_v_ramp  fast_trough_v_short_square  ...  \
# specimen_id                                                  ...
# 529878215            -57.385420                  -57.431251  ...
# 548459652            -54.828129                  -54.656254  ...
# 579978640            -58.234378                  -59.940975  ...
# 439024551            -50.359375                  -65.500000  ...
# 515188639            -46.520837                  -51.406253  ...
#
#              trough_t_ramp  trough_t_short_square  trough_v_long_square  \
# specimen_id
# 529878215        13.295680               1.134780            -56.593754
# 548459652        20.650735               1.160940            -55.406254
# 579978640         2.551960               1.089851            -60.062500
# 439024551         9.576308               1.423229            -49.406254
# 515188639         2.490433               1.479690            -53.000004
#
#              trough_v_ramp  trough_v_short_square  \
# specimen_id
# 529878215       -57.739586             -74.143753
# 548459652       -55.242191             -73.500000
# 579978640       -58.570314             -61.371531
# 439024551       -52.718752             -75.273443
# 515188639       -54.645837             -64.250003
#
#              upstroke_downstroke_ratio_long_square  \
# specimen_id
# 529878215                                 3.029695
# 548459652                                 2.441895
# 579978640                                 2.023762
# 439024551                                 3.105931
# 515188639                                 3.285760
#
#              upstroke_downstroke_ratio_ramp  \
# specimen_id
# 529878215                          3.061646
# 548459652                          2.245653
# 579978640                          2.162878
# 439024551                          3.491663
# 515188639                          3.363504
#
#              upstroke_downstroke_ratio_short_square  vm_for_sag      vrest
# specimen_id
# 529878215                                  2.969821  -80.468750 -73.553391
# 548459652                                  2.231575  -84.406258 -73.056595
# 579978640                                  2.006406  -93.375008 -60.277321
# 439024551                                  1.733896  -87.656250 -75.205559
# 515188639                                  4.234701  -81.625008 -63.474991
#
# [5 rows x 55 columns]

# %% [markdown]
# Now we have two dataframes, one with the metadata for human cells (indexed by id) and another with the electrophysiology data for all cells, also indexed by id. Usefully, these ids are unique to each cell, meaning we can match them across dataframes.
#
# We can use either the `merge` or `join` pandas methods in order to pull all of this data into one dataframe.
#
# ![](http://www.datasciencemadesimple.com/wp-content/uploads/2017/09/join-or-merge-in-python-pandas-1.png)
#
# There are different types of joins/merges you can do in pandas, illustrated <a href="http://www.datasciencemadesimple.com/join-merge-data-frames-pandas-python/">above</a>. Here, we want to do an **inner** merge, where we're only keeping entries with indices that are in both dataframes. We could do this merge based on columns, alternatively.
#
# **Inner** is the default kind of join, so we do not need to specify it. And by default, join will use the 'left' dataframe, in other words, the dataframe that is executing the `join` method.
#
# If you need more information, look at the <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html">join</a> and <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html">merge</a> documentation: you can use either of these to unite your dataframes, though join will be simpler!

# %%
human_ephys_features = human_df.join(ephys_features)
human_ephys_features.head()
# Out:
#           reporter_status     cell_soma_location       species  \
# id
# 525011903            None  [273.0, 354.0, 216.0]  Homo Sapiens
# 528642047            None    [69.0, 254.0, 96.0]  Homo Sapiens
# 537256313            None   [322.0, 255.0, 92.0]  Homo Sapiens
# 519832676            None    [79.0, 273.0, 91.0]  Homo Sapiens
# 596020931            None   [66.0, 220.0, 105.0]  Homo Sapiens
#
#                              name structure_layer_name  structure_area_id  \
# id
# 525011903     H16.03.003.01.14.02                    3              12113
# 528642047  H16.06.009.01.02.06.05                    5              12141
# 537256313     H16.03.006.01.05.02                    4              12141
# 519832676     H16.03.001.01.09.01                    3              12141
# 596020931     H17.06.009.11.04.02                    4              12141
#
#           structure_area_abbrev transgenic_line dendrite_type     apical  ...  \
# id                                                                        ...
# 525011903                  FroL                         spiny     intact  ...
# 528642047                   MTG                        aspiny         NA  ...
# 537256313                   MTG                         spiny  truncated  ...
# 519832676                   MTG                         spiny  truncated  ...
# 596020931                   MTG                        aspiny         NA  ...
#
#           trough_t_ramp trough_t_short_square  trough_v_long_square  \
# id
# 525011903      4.134987              1.375253            -53.968754
# 528642047           NaN              1.051160            -67.468758
# 537256313      5.694547              1.389900            -52.125004
# 519832676      9.962780              1.211020            -53.875004
# 596020931     14.667340              1.336668            -63.593754
#
#           trough_v_ramp  trough_v_short_square  \
# id
# 525011903    -59.510420             -71.197919
# 528642047           NaN             -70.875002
# 537256313    -51.520836             -72.900002
# 519832676    -52.416668             -73.693753
# 596020931    -63.239583             -75.518753
#
#            upstroke_downstroke_ratio_long_square  \
# id
# 525011903                               2.895461
# 528642047                               1.891881
# 537256313                               3.121182
# 519832676                               4.574865
# 596020931                               1.452890
#
#            upstroke_downstroke_ratio_ramp  \
# id
# 525011903                        2.559876
# 528642047                             NaN
# 537256313                        3.464528
# 519832676                        3.817988
# 596020931                        1.441754
#
#            upstroke_downstroke_ratio_short_square  vm_for_sag      vrest
# id
# 525011903                                3.099787  -88.843758 -70.561035
# 528642047                                1.989616 -101.000000 -69.209610
# 537256313                                3.054681  -87.531250 -72.628105
# 519832676                                4.980603  -84.218758 -72.547661
# 596020931                                1.556087  -82.531250 -74.260269
#
# [5 rows x 70 columns]

# %% [markdown]
# ## Step Three: Confirm the data and take a look!
#
# As a result, you should have a dataframe called 'human_ephys_features' that contains metadata about your cells, as well as their electrophysiological properties.
#
# 1. Confirm that you have right amount of data by checking it's length using a Boolean to test whether it is equal to `n_human_cells` that you assigned above.
# 2. Confirm that you have all of the columns from *both* the human_df and ephys_features dataframes programmatically. Remember that you can get the columns by accessing the `columns` attribute, and that you already assigned the human_df columns to a variable above. There are a few different ways to do this!
# 3. Confirm that the only 'species' in your `human_ephys_features` dataframe is 'Homo Sapiens'. You can use the `unique()` method to show unique values in a column.

# %%
print(n_human_cells == len(human_ephys_features))

all_columns = list(ephys_features.columns) + list(human_df_columns)
complete_final_list = list(human_ephys_features.columns)

print(len(all_columns) == len(complete_final_list))

print(human_ephys_features['dendrite_type'].unique())
# Out:
# True
# True
# ['spiny' 'aspiny' 'sparsely spiny']

# %% [markdown]
# *Finally*, let's take a look at the data. You can use the `describe()` method to show the basic statistics for your cells. We'll start plotting these metrics next week!

# %%
human_ephys_features.head()
# Out:
#           reporter_status     cell_soma_location       species  \
# id
# 525011903            None  [273.0, 354.0, 216.0]  Homo Sapiens
# 528642047            None    [69.0, 254.0, 96.0]  Homo Sapiens
# 537256313            None   [322.0, 255.0, 92.0]  Homo Sapiens
# 519832676            None    [79.0, 273.0, 91.0]  Homo Sapiens
# 596020931            None   [66.0, 220.0, 105.0]  Homo Sapiens
#
#                              name structure_layer_name  structure_area_id  \
# id
# 525011903     H16.03.003.01.14.02                    3              12113
# 528642047  H16.06.009.01.02.06.05                    5              12141
# 537256313     H16.03.006.01.05.02                    4              12141
# 519832676     H16.03.001.01.09.01                    3              12141
# 596020931     H17.06.009.11.04.02                    4              12141
#
#           structure_area_abbrev transgenic_line dendrite_type     apical  ...  \
# id                                                                        ...
# 525011903                  FroL                         spiny     intact  ...
# 528642047                   MTG                        aspiny         NA  ...
# 537256313                   MTG                         spiny  truncated  ...
# 519832676                   MTG                         spiny  truncated  ...
# 596020931                   MTG                        aspiny         NA  ...
#
#           trough_t_ramp trough_t_short_square  trough_v_long_square  \
# id
# 525011903      4.134987              1.375253            -53.968754
# 528642047           NaN              1.051160            -67.468758
# 537256313      5.694547              1.389900            -52.125004
# 519832676      9.962780              1.211020            -53.875004
# 596020931     14.667340              1.336668            -63.593754
#
#           trough_v_ramp  trough_v_short_square  \
# id
# 525011903    -59.510420             -71.197919
# 528642047           NaN             -70.875002
# 537256313    -51.520836             -72.900002
# 519832676    -52.416668             -73.693753
# 596020931    -63.239583             -75.518753
#
#            upstroke_downstroke_ratio_long_square  \
# id
# 525011903                               2.895461
# 528642047                               1.891881
# 537256313                               3.121182
# 519832676                               4.574865
# 596020931                               1.452890
#
#            upstroke_downstroke_ratio_ramp  \
# id
# 525011903                        2.559876
# 528642047                             NaN
# 537256313                        3.464528
# 519832676                        3.817988
# 596020931                        1.441754
#
#            upstroke_downstroke_ratio_short_square  vm_for_sag      vrest
# id
# 525011903                                3.099787  -88.843758 -70.561035
# 528642047                                1.989616 -101.000000 -69.209610
# 537256313                                3.054681  -87.531250 -72.628105
# 519832676                                4.980603  -84.218758 -72.547661
# 596020931                                1.556087  -82.531250 -74.260269
#
# [5 rows x 70 columns]
